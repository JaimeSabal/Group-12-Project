# %%
from Functions import *

# %%
windowsize = 7
estimatedNumCrossings = 2
year=2005
start_day1 =130.75
end_day1 = 131.5

day_data1_2004 = get_day_data(start_day1, end_day1, year)
#plot_KSM(day_data1_2004, year, start_day1, end_day1, xFormat = "Hour")
entries1, exits1, ax1, ksmcoords_1,cross_array1 = identify_crossings_2(day_data1_2004, windowsize, estimatedNumCrossings,3,2,100)
plt.title("Crossings Identified (Days {}-{}, {})".format(start_day1, end_day1,year),fontsize = 14)
print(cross_array1)
# Out:
# Sample start date:  2005-05-10 18:00:30
# Sample end date: 2005-05-11 12:00:30
# ['2005-05-10 20:48:30', '2005-05-10 21:25:30', '2005-05-11 00:47:30']

# %%
estimatedNumCrossings = 15

start_day2 = 134
end_day2 = 136.7
day_data2_2004 = get_day_data(start_day2, end_day2, year)
#plot_KSM(day_data2_2004, year, start_day2, end_day2, xFormat = "Hour")
entries2, exits2, ax2, ksmcoords_2,cross_array2 = identify_crossings_2(day_data2_2004, windowsize, estimatedNumCrossings,3,2,60)
plt.title("Crossings Identified (Days {}-{}, {})".format(start_day2, end_day2,year),fontsize = 14)

del cross_array2[1:6]
del cross_array2[2]
print(cross_array2)
# Out:
# Sample start date:  2005-05-14 00:00:30
# Sample end date: 2005-05-16 16:48:30
# ['2005-05-14 05:42:30', '2005-05-16 01:57:30', '2005-05-16 06:01:30', '2005-05-16 10:26:30', '2005-05-16 14:37:30', '2005-05-16 15:21:30', '2005-05-16 15:44:30']

# %%
estimatedNumCrossings = 25
start_day3 =148.6
end_day3 = 156

day_data3_2004 = get_day_data(start_day3, end_day3, year)
#plot_KSM(day_data1_2004, year, start_day1, end_day1, xFormat = "Hour")
entries3, exits3, ax3, ksmcoords_3,cross_array3 = identify_crossings_2(day_data3_2004, windowsize, estimatedNumCrossings,3,2,200)
plt.title("Crossings identified (Days {}-{}, {})".format(start_day3, end_day3,year),fontsize = 14)


print(cross_array3)
# Out:
# Sample start date:  2005-05-28 14:24:30
# Sample end date: 2005-06-05 00:00:30
# ['2005-05-28 16:39:30', '2005-06-01 16:15:30', '2005-06-01 17:06:30', '2005-06-01 19:41:30', '2005-06-01 21:43:30', '2005-06-02 01:10:30', '2005-06-02 04:58:30', '2005-06-02 18:33:30', '2005-06-02 20:20:30', '2005-06-03 11:04:30', '2005-06-03 20:47:30', '2005-06-03 21:32:30', '2005-06-04 03:24:30', '2005-06-04 06:03:30', '2005-06-04 08:49:30', '2005-06-04 10:44:30', '2005-06-04 18:37:30', '2005-06-04 20:42:30', '2005-06-04 23:44:30']

# %%
cross_array = cross_array1 + cross_array2+cross_array3
print('crossing dates',cross_array)
day_data_2004 = get_day_data(start_day1,end_day3,year)
day_data_2004.index.strftime('%Y-%m-%d %H:%M:%S')
# Out:
# crossing dates ['2005-05-10 20:48:30', '2005-05-10 21:25:30', '2005-05-11 00:47:30', '2005-05-14 05:42:30', '2005-05-16 01:57:30', '2005-05-16 06:01:30', '2005-05-16 10:26:30', '2005-05-16 14:37:30', '2005-05-16 15:21:30', '2005-05-16 15:44:30', '2005-05-28 16:39:30', '2005-06-01 16:15:30', '2005-06-01 17:06:30', '2005-06-01 19:41:30', '2005-06-01 21:43:30', '2005-06-02 01:10:30', '2005-06-02 04:58:30', '2005-06-02 18:33:30', '2005-06-02 20:20:30', '2005-06-03 11:04:30', '2005-06-03 20:47:30', '2005-06-03 21:32:30', '2005-06-04 03:24:30', '2005-06-04 06:03:30', '2005-06-04 08:49:30', '2005-06-04 10:44:30', '2005-06-04 18:37:30', '2005-06-04 20:42:30', '2005-06-04 23:44:30']
# Sample start date:  2005-05-10 18:00:30
# Sample end date: 2005-06-05 00:00:30
# Index(['2005-05-10 18:00:30', '2005-05-10 18:01:30', '2005-05-10 18:02:30',
#        '2005-05-10 18:03:30', '2005-05-10 18:04:30', '2005-05-10 18:05:30',
#        '2005-05-10 18:06:30', '2005-05-10 18:07:30', '2005-05-10 18:08:30',
#        '2005-05-10 18:09:30',
#        ...
#        '2005-06-04 23:50:30', '2005-06-04 23:51:30', '2005-06-04 23:52:30',
#        '2005-06-04 23:53:30', '2005-06-04 23:54:30', '2005-06-04 23:55:30',
#        '2005-06-04 23:56:30', '2005-06-04 23:57:30', '2005-06-04 23:58:30',
#        '2005-06-04 23:59:30'],
#       dtype='object', name='Time', length=34879)

# %%
offset=4
mins=8+offset

b1, b2 = extract_B_vector3(cross_array, day_data_2004, mins,offset)

type1 = ['exit', 'entry', 'exit',
         'entry', 'exit','entry', 'exit', 'entry', 'exit' ,'entry',
         'exit','entry','exit', 'entry', 'exit' ,'entry', 'exit','entry', 'exit', 'entry', 'exit' ,'entry', 'entry','exit','entry','exit', 'entry', 'exit' ,'entry']
num = np.arange(1, len(cross_array)+1, 1)

ncp,ave_ncp,std_ncp,shock_v,ave_shock, std = ncp_shock3(b1, b2, 8, num, type1)
# Out:
# S=1 θ_BN value = 48.261021021760655
# Standard deviation = 13.294208313459174
# S=2 θ_BN value = 40.44596878771601
# Standard deviation = 21.107689506469587
# S=3 θ_BN value = 53.937674670575284
# Standard deviation = 6.065964181210094
# S=4 θ_BN value = 52.924667783479485
# Standard deviation = 7.7794176770378645
# S=5 θ_BN value = 40.1771474364213
# Standard deviation = 14.87693786617101
# S=6 θ_BN value = 75.93480816225767
# Standard deviation = 5.32947626474718
# S=7 θ_BN value = 64.01476499962818
# Standard deviation = 3.1535546581866463
# S=8 θ_BN value = 61.61018780449601
# Standard deviation = 9.223172056802454
# S=9 θ_BN value = 19.03230094936872
# Standard deviation = 9.452951789013099
# S=10 θ_BN value = 30.25966994185335
# Standard deviation = 17.751687470924853
# S=11 θ_BN value = 63.84756315954773
# Standard deviation = 6.398477315207399
# S=12 θ_BN value = 58.469163652592755
# Standard deviation = 4.479057431464145
# S=13 θ_BN value = 78.16104413834317
# Standard deviation = 4.079141057646669
# S=14 θ_BN value = 79.10678262064866
# Standard deviation = 4.825187503451592
# S=15 θ_BN value = 78.1804362822603
# Standard deviation = 2.840090264526578
# S=16 θ_BN value = 83.38793665184608
# Standard deviation = 3.127611096585782
# S=17 θ_BN value = 64.46054925900147
# Standard deviation = 6.86165010538211
# S=18 θ_BN value = 77.75193307406127
# Standard deviation = 4.479013411974999
# S=19 θ_BN value = 40.33042829612933
# Standard deviation = 3.78058797785169
# S=20 θ_BN value = 67.34559186651379
# Standard deviation = 2.1508080770248834
# S=21 θ_BN value = 83.93721233884474
# Standard deviation = 3.106630669481269
# S=22 θ_BN value = 80.39048592682266
# Standard deviation = 4.439398168899886
# S=23 θ_BN value = 61.19630490623336
# Standard deviation = 6.2139488227975885
# S=24 θ_BN value = 59.0649015800724
# Standard deviation = 2.107168205332989
# S=25 θ_BN value = 54.529061001158546
# Standard deviation = 4.927817752096183
# S=26 θ_BN value = 53.49627346792073
# Standard deviation = 9.996677015191501
# S=27 θ_BN value = 63.105412898976525
# Standard deviation = 16.172243327505544
# S=28 θ_BN value = 62.71521590646542
# Standard deviation = 5.089029956073671
# S=29 θ_BN value = 66.10841855226897
# Standard deviation = 6.064275315572136

# %%
Plot_Dist_for_theta([*shock_v])
plt.title("Kurtosis vs Skewness (Days 130-156, 2005)", fontsize = 15)
plt.xlabel("Kurtosis of ${\Theta}_{BN}$", fontsize = 15)
plt.ylabel("Skewness of ${\Theta}_{BN}$", fontsize = 15)
# Out:
# Text(0, 0.5, 'Skewness of ${\\Theta}_{BN}$')

# %%
plt.figure(figsize = (10,12))
x_ncp,rho_ncp,srho_ncp=plotncp(day_data_2004,cross_array,2,ave_ncp,std_ncp,0,4)
plt.ylim(10,50)
plt.xlim(7.5,25)
plt.xlabel(r"$X_{KSM}  \left(R_s\right)$",fontsize = 12)
plt.ylabel(r"$\left(Y_{KSM}^2 + Z_{KSM}^2\right)^{1/2} \left(R_s\right)$",fontsize = 12)
plt.title("Projections of Co-planarity Normals (Days 130-156, 2005)", fontsize = 15)

plt.gca().invert_yaxis()

# %%
t,st=calCPM(day_data_2004,cross_array,ave_ncp,rho_ncp,std_ncp,srho_ncp)
plt.ylim(35,40)
plt.xlim(12,16 )
plt.xlabel(r"$X_{KSM}  \left(R_s\right)$",fontsize = 12)
plt.ylabel(r"$\left(Y_{KSM}^2 + Z_{KSM}^2\right)^{1/2} \left(R_s\right)$",fontsize = 12)
plt.title('A Representations of Norm Vectors (Days 130-156, 2005)',fontsize = 15)
# Out:
# Theta_CPM  [45.087434986763895, 11.039534605774904, 7.476554934875935, 6.291482930084882, 18.170857458325187, 27.18461465629302, 8.71309109392277, 20.527445999537193, 57.89549473919607, 65.16435569653362, 1.6488077298809998, 11.358556464477942, 77.94829326352891, 34.11112646094521, 17.654951006632842, 25.41240194794422, 80.81938119754182, 3.410909941997403, 23.255235939344686, 0.05791648043305031, 11.18707049408114, 27.65287950962191, 57.71882247592274, 0.8835958909252355, 2.811182710205344, 27.471502694662888, 27.60629363421134, 11.031100057509988, 10.931541242014589]
# Std [30.77286534495866, 20.37003443925872, 11.178165493198206, 6.520374030472656, 11.042695226722547, 34.31326489152642, 6.946515309749022, 14.000620243632465, 6.565340937570394, 14.218845113549596, 7.550745785105843, 2.7124200040672637, 31.12237667381841, 34.8319067855574, 22.36164578658683, 31.016661322310963, 9.82204296801083, 9.400322363545413, 2.7409275136804143, 5.935634763624682, 24.248643197706645, 25.368001547907085, 5.455861383141751, 2.5574873846852504, 9.68880161876014, 22.719907716263403, 21.55064251228969, 18.7347494637571, 7.140206219320583]
# Text(0.5, 1.0, 'A Representations of Norm Vectors (Days 130-156, 2005)')

# %%
plt.figure()
plt.plot(ave_shock,t,'.')
plt.xlabel('shock angle ${\Theta}_{BN}$',fontsize = 12)
plt.ylabel('Angle between model and coplanarity normals ${\Theta}_{CPM}$ ', fontsize = 12)
plt.errorbar(ave_shock,t,xerr=std,yerr=st,fmt='o',color='k')
plt.title('Shock Angle ${\Theta}_{BN}$ vs ${\Theta}_{CPM}$ (Days 130-156, 2005)',fontsize = 15)
plt.ylim(-10,100)
plt.xlim(0,90 )
for i in range(len(srho_ncp)):
    S='S'+str(i+1)
    plt.annotate(S, (ave_shock[i],t[i]+1) )

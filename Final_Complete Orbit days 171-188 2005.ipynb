# %%
from Functions import *

# %%
windowsize = 7
estimatedNumCrossings = 26
year=2005
start_day1 =171.1
end_day1 = 175.4

day_data1_2004 = get_day_data(start_day1, end_day1, year)
#plot_KSM(day_data1_2004, year, start_day1, end_day1, xFormat = "Hour")
entries1, exits1, ax1, ksmcoords_1,cross_array1 = identify_crossings_2(day_data1_2004, windowsize, estimatedNumCrossings,3,2,299)
plt.title("Crossings Identified (Days {}-{}, {})".format(start_day1, end_day1,year),fontsize = 14)

print(cross_array1)
# Out:
# Sample start date:  2005-06-20 02:24:30
# Sample end date: 2005-06-24 09:36:30
# ['2005-06-20 08:07:30', '2005-06-20 15:20:30', '2005-06-20 15:43:30', '2005-06-21 14:31:30', '2005-06-21 17:55:30', '2005-06-22 09:00:30', '2005-06-22 12:06:30', '2005-06-23 05:30:30', '2005-06-23 06:34:30', '2005-06-23 12:24:30', '2005-06-23 14:13:30', '2005-06-23 17:27:30', '2005-06-23 19:59:30', '2005-06-24 00:46:30', '2005-06-24 06:10:30', '2005-06-24 07:20:30']

# %%
estimatedNumCrossings = 15

start_day2 = 182
end_day2 = 189
day_data2_2004 = get_day_data(start_day2, end_day2, year)
#plot_KSM(day_data2_2004, year, start_day2, end_day2, xFormat = "Hour")
entries2, exits2, ax2, ksmcoords_2,cross_array2 = identify_crossings_2(day_data2_2004, windowsize, estimatedNumCrossings,3,2,130)
plt.title("Crossings Identified (Days {}-{}, {})".format(start_day2, end_day2,year),fontsize = 14)

del cross_array2[-3]
print(cross_array2)
# Out:
# Sample start date:  2005-07-01 00:00:30
# Sample end date: 2005-07-08 00:00:30
# ['2005-07-01 03:24:30', '2005-07-01 15:21:30', '2005-07-01 18:49:30', '2005-07-01 20:42:30', '2005-07-02 05:13:30', '2005-07-02 09:43:30', '2005-07-02 17:21:30', '2005-07-02 20:21:30', '2005-07-03 14:41:30', '2005-07-03 17:34:30', '2005-07-03 18:23:30', '2005-07-03 22:03:30', '2005-07-04 00:06:30', '2005-07-04 18:00:30', '2005-07-06 16:14:30', '2005-07-06 19:24:30', '2005-07-07 18:54:30', '2005-07-07 22:47:30']

# %%
cross_array = cross_array1 + cross_array2
print('crossing dates',cross_array)
day_data_2004 = get_day_data(start_day1,end_day2,year)
day_data_2004.index.strftime('%Y-%m-%d %H:%M:%S')
print(len(cross_array))
# Out:
# crossing dates ['2005-06-20 08:07:30', '2005-06-20 15:20:30', '2005-06-20 15:43:30', '2005-06-21 14:31:30', '2005-06-21 17:55:30', '2005-06-22 09:00:30', '2005-06-22 12:06:30', '2005-06-23 05:30:30', '2005-06-23 06:34:30', '2005-06-23 12:24:30', '2005-06-23 14:13:30', '2005-06-23 17:27:30', '2005-06-23 19:59:30', '2005-06-24 00:46:30', '2005-06-24 06:10:30', '2005-06-24 07:20:30', '2005-07-01 03:24:30', '2005-07-01 15:21:30', '2005-07-01 18:49:30', '2005-07-01 20:42:30', '2005-07-02 05:13:30', '2005-07-02 09:43:30', '2005-07-02 17:21:30', '2005-07-02 20:21:30', '2005-07-03 14:41:30', '2005-07-03 17:34:30', '2005-07-03 18:23:30', '2005-07-03 22:03:30', '2005-07-04 00:06:30', '2005-07-04 18:00:30', '2005-07-06 16:14:30', '2005-07-06 19:24:30', '2005-07-07 18:54:30', '2005-07-07 22:47:30']
# Sample start date:  2005-06-20 02:24:30
# Sample end date: 2005-07-08 00:00:30
# 34

# %%
offset=4
mins=8+offset

b1, b2 = extract_B_vector3(cross_array, day_data_2004, mins,offset)

type1 = ['exit','entry', 'exit', 'entry', 'exit' ,'entry', 'exit','entry', 'exit', 'entry', 'exit' ,'entry', 'exit','entry', 'exit','entry', 'exit','entry',
        'exit','entry', 'exit', 'entry', 'exit' ,'entry', 'exit','entry', 'exit', 'entry', 'exit' ,'entry', 'exit' ,'entry', 'exit' ,'entry']
num = np.arange(1, len(cross_array)+1, 1)

ncp,ave_ncp,std_ncp,shock_v,ave_shock, std = ncp_shock3(b1, b2, 8, num, type1)
# Out:
# S=1 θ_BN value = 21.344213861299878
# Standard deviation = 15.73970405466692
# S=2 θ_BN value = 33.714179678920594
# Standard deviation = 22.302917862650844
# S=3 θ_BN value = 39.09992163946388
# Standard deviation = 25.663142371150226
# S=4 θ_BN value = 38.49450857972634
# Standard deviation = 20.76497468074534
# S=5 θ_BN value = 35.1502278659471
# Standard deviation = 9.666181572709126
# S=6 θ_BN value = 69.95817010473807
# Standard deviation = 6.353041482630532
# S=7 θ_BN value = 37.920761024066934
# Standard deviation = 22.44995938536437
# S=8 θ_BN value = 55.377618252278985
# Standard deviation = 7.963182736849241
# S=9 θ_BN value = 28.979892338762834
# Standard deviation = 13.878983364748489
# S=10 θ_BN value = 49.580160216470745
# Standard deviation = 9.889902442618892
# S=11 θ_BN value = 68.73802057223338
# Standard deviation = 13.511833804585168
# S=12 θ_BN value = 68.87646161826686
# Standard deviation = 11.52750621804668
# S=13 θ_BN value = 74.32861566270303
# Standard deviation = 3.201792237524209
# S=14 θ_BN value = 16.488626308787346
# Standard deviation = 11.740290365754669
# S=15 θ_BN value = 78.59378584532294
# Standard deviation = 4.877035420407049
# S=16 θ_BN value = 56.535995622068555
# Standard deviation = 15.358731337095632
# S=17 θ_BN value = 52.44815756894464
# Standard deviation = 18.15686750991234
# S=18 θ_BN value = 51.31504337115574
# Standard deviation = 11.712574450609504
# S=19 θ_BN value = 78.13259164225937
# Standard deviation = 5.309423398092761
# S=20 θ_BN value = 48.888260390353054
# Standard deviation = 23.125054030294717
# S=21 θ_BN value = 30.752475373646647
# Standard deviation = 18.709122663663752
# S=22 θ_BN value = 36.721560216604445
# Standard deviation = 21.84721525292146
# S=23 θ_BN value = 24.455408891617786
# Standard deviation = 16.820634613018623
# S=24 θ_BN value = 36.85798928499691
# Standard deviation = 17.71239137777766
# S=25 θ_BN value = 53.00345844804008
# Standard deviation = 3.504868100301769
# S=26 θ_BN value = 51.35315367702608
# Standard deviation = 2.9401807414069774
# S=27 θ_BN value = 71.83233841600261
# Standard deviation = 9.953925675190312
# S=28 θ_BN value = 57.01663847712899
# Standard deviation = 1.8854322649755535
# S=29 θ_BN value = 19.40379236383913
# Standard deviation = 8.502965740121574
# S=30 θ_BN value = 80.54688059643863
# Standard deviation = 2.7772892909566247
# S=31 θ_BN value = 71.37589187641083
# Standard deviation = 6.856584968400057
# S=32 θ_BN value = 69.15847059922478
# Standard deviation = 6.084494007292112
# S=33 θ_BN value = 57.27753861806711
# Standard deviation = 7.099342025460097
# S=34 θ_BN value = 71.20409067141387
# Standard deviation = 7.982529463583965

# %%
Plot_Dist_for_theta([*shock_v])
plt.title("Kurtosis vs Skewness (Days 171-188, 2005)", fontsize = 15)
plt.xlabel("Kurtosis of ${\Theta}_{BN}$", fontsize = 15)
plt.ylabel("Skewness of ${\Theta}_{BN}$", fontsize = 15)

# %%
x_ncp,rho_ncp,srho_ncp=plotncp(day_data_2004,cross_array,3,ave_ncp,std_ncp,-1,17)
plt.xlabel(r"$X_{KSM}  \left(R_s\right)$",fontsize = 12)
plt.ylabel(r"$\left(Y_{KSM}^2 + Z_{KSM}^2\right)^{1/2} \left(R_s\right)$",fontsize = 12)
plt.title("Projections of Co-planarity Normals (Days 171-188, 2005)", fontsize = 15)
plt.ylim(0,50)
plt.xlim(-15,25)
plt.gca().invert_yaxis()

# %%
t,st=calCPM(day_data_2004,cross_array,ave_ncp,rho_ncp,std_ncp,srho_ncp)
plt.xlabel(r"$X_{KSM}  \left(R_s\right)$",fontsize = 12)
plt.ylabel(r"$\left(Y_{KSM}^2 + Z_{KSM}^2\right)^{1/2} \left(R_s\right)$",fontsize = 12)
plt.title('A Representation of Norm Vectors (Days 171-188, 2005)',fontsize = 15)
plt.ylim(31,33.5)
plt.xlim(19.5,22.5)
# Out:
# Theta_CPM  [77.81397514083467, 49.60591614727067, 39.23913759630179, 83.96181023398616, 3.6138884103721267, 72.29089519380048, 28.76045654275078, 15.67982850829695, 35.49732876576452, 19.597824417900412, 26.23165393299665, 88.59623111551554, 12.57762742889247, 73.07106488095059, 15.322155385699915, 75.0858765624142, 24.759317223112234, 18.32984202320867, 2.740671599108154, 57.6749077056804, 22.693196662414664, 54.9604076693523, 40.496953306222046, 34.05899557630303, 0.7466781080697729, 3.312878144832254, 85.29071750525637, 21.23685549322279, 30.91013837272868, 11.798776570189034, 12.330164233929821, 12.88510236125174, 1.322078597560406, 12.811773875113957]
# Std [6.215660974121432, 32.20958827527746, 35.3777521633721, 25.696325684425386, 8.946611245556937, 39.231581044586044, 21.2465394987645, 7.2010029376231905, 9.290524056719665, 7.494256505465968, 24.880881447933216, 26.57987200247005, 4.776963384784347, 2.1979147975726376, 14.555735285641893, 19.797486583977026, 14.809120477802617, 18.140610951333567, 20.211022240732905, 39.97992697056143, 23.599488868613957, 32.120629937478654, 27.502250574957507, 12.030727102304846, 3.400109488599087, 3.4688742970916446, 37.00924392207326, 4.796385118346094, 6.010833773272496, 29.49375669404367, 21.765248173326384, 31.182412347519676, 6.169422660420482, 13.882552129457995]
# (19.5, 22.5)

# %%
#for i in range(len(st)):
    #st[i]=st[i]/2
    #std[i]=std[i]/2
plt.figure()
plt.plot(ave_shock,t,'.')
plt.xlabel('Shock Angle ${\Theta}_{BN}$',fontsize = 12)
plt.ylabel('Angle Between Model and Co-planarity Normals ${\Theta}_{CPM}$ ',fontsize = 12)
plt.title('Shock Angle ${\Theta}_{BN}$ vs ${\Theta}_{CPM}$ (Days 171-188, 2005)',fontsize = 15)
plt.errorbar(ave_shock,t,xerr=std,yerr=st,fmt='o',color='k')
plt.ylim(-10,100)
plt.xlim(0,90 )
for i in range(len(srho_ncp)):
    S='S'+str(i+1)
    plt.annotate(S, (ave_shock[i],t[i]+1) )
